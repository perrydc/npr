# %%
from unittest import TestCase
import random
import importlib.util
spec = importlib.util.spec_from_file_location("npr", "../npr/__init__.py")
npr = importlib.util.module_from_spec(spec)
spec.loader.exec_module(npr)

# %%
explore = npr.Channels()
explore.fetch(0)
explore.row.pretty()
# Out:
# {
#   "attributes": {},
#   "errors": [],
#   "href": "https://listening.api.npr.org/v2/recommendations?channel=npr",
#   "items": [],
#   "links": {},
#   "version": "1.0"
# }

# %%
npr.login()
# Out:
# Go to https://npr.org/device login and enter:
# 1LLO6E
# User logged in and stored locally

# %%
stories = npr.Stories() # lookup top stories
#stories.links
stories.pretty()
# Out:
# {
#   "errors": [
#     {
#       "text": "Unauthorized"
#     }
#   ]
# }

# %%
story = npr.Story(565664321) # lookup story by id
story.a
# Out:
# {'error': 'try .pretty() to trouble-shoot'}

# %%
s = npr.Search('hidden')
s.stories
# Out:
# [{'credit': 'Sean Murphy/Getty Images',
#   'date': '2017-12-01T05:04:00-05:00',
#   'image': 'https://media.npr.org/assets/img/2017/12/07/gettyimages-166076051_wide-4c3081a772aa771ef90d29317a6fe703fb52a09e.jpg?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=567688882:567688883',
#   'program': 'morning edition',
#   'title': 'How Birth Order Relates To Job Success'},
#  {'credit': '',
#   'date': '2018-03-26T14:35:53-04:00',
#   'image': '',
#   'link': 'https://one.npr.org/?sharedMediaId=596989664:597066785',
#   'program': 'fresh air',
#   'title': "How American Corporations Had A 'Hidden' Civil Rights Movement"},
#  {'credit': 'Laura Ruocco/Montefiore Medical Center',
#   'date': '2018-06-04T21:00:31-04:00',
#   'image': 'https://media.npr.org/assets/img/2018/06/04/photo-apr-03-12-17-12-pm---martin_wide-e9d53ac9d109893cfbfe6198a9742575ce7a175b.jpg?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=616127481:616897281',
#   'program': '',
#   'title': 'When Everything Clicks: The Power Of Judgment-Free Learning'},
#  {'credit': '',
#   'date': '2018-03-06T05:02:00-05:00',
#   'image': 'https://media.npr.org/assets/img/2018/02/27/meiconv2_sq-0aa415f5a37ab264bc360cc72c8b6a2202cd5cd4.png?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=591085358:591085359',
#   'program': 'morning edition',
#   'title': 'Hidden Brain: Relationship Between Having Babies And The Economy'},
#  {'credit': 'Patrick Gillooly/MIT News Office',
#   'date': '2018-05-28T22:35:55-04:00',
#   'image': 'https://media.npr.org/assets/img/2018/05/24/d20110630162840-0_wide-c18fec396f5dae5121ea37a7355a4d93f6ad6ba8.jpg?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=614054515:614517459',
#   'program': '',
#   'title': 'The Carpenter Vs. The Gardener: Two Models Of Modern Parenting'},
#  {'credit': 'Jess Milton/Getty Images',
#   'date': '2018-05-24T17:04:28-04:00',
#   'image': 'https://media.npr.org/assets/img/2018/05/23/gettyimages-858030616_wide-12f130aa56a52e73a9aef69606df74b00e558745.jpg?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=613831952:614195053',
#   'program': '',
#   'title': "Don't Panic! What We Can Learn From Chaos"},
#  {'credit': 'Courtesy of Laura Odgen',
#   'date': '2018-05-21T21:00:34-04:00',
#   'image': 'https://media.npr.org/assets/img/2018/05/18/img_3527_wide-3faa8be4a9d83462da5793def46df0bdbcbc1eae.jpg?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=612458913:613127761',
#   'program': '',
#   'title': 'Rewinding & Rewriting: The Alternate Universes in Our Heads'},
#  {'credit': 'Westend61/Getty Images/Westend61',
#   'date': '2018-05-14T21:00:00-04:00',
#   'image': 'https://media.npr.org/assets/img/2018/05/13/gettyimages-748330723_wide-5b7ae6133d59699a8037536eca0afd90a1a06c47.jpg?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=610796636:611111874',
#   'program': '',
#   'title': 'Baby Talk: Decoding The Secret Language Of Babies'},
#  {'credit': 'Phillip Waterman/Getty Images/Cultura RF',
#   'date': '2018-05-18T18:51:01-04:00',
#   'image': 'https://media.npr.org/assets/img/2018/05/17/this-is-your-brain-on-ads_wide-862956455ca30340103854a9641a14ff86775ef1.jpg?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=612037491:612355713',
#   'program': '',
#   'title': 'Radio Replay: This Is Your Brain On Ads'},
#  {'credit': 'Julian Dunn/Flickr',
#   'date': '2016-09-20T17:25:00-04:00',
#   'image': 'https://media.npr.org/assets/img/2016/09/20/6804357954_dbca071529_o-edit_wide-3127c15120c067e638d0cdc6922db8031a878f33.jpg?s=600',
#   'link': 'https://one.npr.org/?sharedMediaId=494733654:494765592',
#   'program': 'all things considered',
#   'title': "'Atlas Obscura' Tour Of Manhattan Finds Hidden Wonders In A Well-Trodden Place"}]

# %%
s = npr.Stations('wamu')
s.find('The Kojo Nnamdi Show: Politics Hour')
# Out:
# The Kojo Nnamdi Show: Politics Hour .response['items'][0]['links']['podcasts'][0]['title']

# %%
# unwrap function
station = npr.Station(305)
station.unwrap(station.stream)
# Out:
# 'https://hd1.wamu.org/wamu-1.aac'

# %%
story = npr.Story(565664321) # lookup story by id
#story.title
story.a
# Out:
# {'error': 'try .pretty() to trouble-shoot'}

# %%
#find a station from a random (possibly invalid) orgid
orgId = random.randrange(2, 500)
station = npr.Station(orgId)
station.a
# Out:
# {'id': '301',
#  'mp3': 'https://playerservices.streamtheworld.com/pls/WAMCHD2.pls',
#  'name': 'Northeast Public Radio',
#  'stream': 'https://playerservices.streamtheworld.com/pls/WAMCFMAAC.pls'}

# %%
#station roulette!
stations = npr.Stations(42.3601, -71.0589)
print(stations.name)
# Out:
# WGBH Radio

# %%
stations = npr.Stations('22205')
for station in stations.station:
    if 'stream' in station:
        print(station['stream'])
# Out:
# https://static.wamu.org/streams/live/1/live_aac_ssl.pls
# https://stream.weta.org:8010/fmlive
# https://wtmd-ice.streamguys1.com/wtmd.mp3
# https://playerservices.streamtheworld.com/api/livestream-redirect/WYPR_HD1.mp3

# %%
query = npr.Search('hidden')
query.response['items'][0]['attributes']['description']
# Out:
# 'Shankar Vedantam uses science and storytelling to reveal the unconscious patterns that drive human behavior, shape our choices and direct our relationships.'

# %%
u = npr.User()
u.pretty()
# Out:
# {
#   "attributes": {
#     "affiliations": [
#       {
#         "daysSinceLastListen": 48,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/13/recommendations",
#         "id": "13",
#         "notif_following": {
#           "default": "/topics/prod_followed_13",
#           "ios": "/topics/prod_followed_IOS_13"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_13",
#           "ios": "/topics/prod_rated_IOS_13"
#         },
#         "rating": 0.2,
#         "title": "Fresh Air"
#       },
#       {
#         "daysSinceLastListen": 177,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/344098539/recommendations",
#         "id": "344098539",
#         "notif_following": {
#           "default": "/topics/prod_followed_344098539",
#           "ios": "/topics/prod_followed_IOS_344098539"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_344098539",
#           "ios": "/topics/prod_rated_IOS_344098539"
#         },
#         "rating": 0.64,
#         "title": "Wait Wait... Don't Tell Me!"
#       },
#       {
#         "daysSinceLastListen": 141,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/368757304/recommendations",
#         "id": "368757304",
#         "notif_following": {
#           "default": "/topics/prod_followed_368757304",
#           "ios": "/topics/prod_followed_IOS_368757304"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_368757304",
#           "ios": "/topics/prod_rated_IOS_368757304"
#         },
#         "rating": 0.68,
#         "title": "The Moth"
#       },
#       {
#         "daysSinceLastListen": 475,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/381443486/recommendations",
#         "id": "381443486",
#         "notif_following": {
#           "default": "/topics/prod_followed_381443486",
#           "ios": "/topics/prod_followed_IOS_381443486"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381443486",
#           "ios": "/topics/prod_rated_IOS_381443486"
#         },
#         "rating": 0.7,
#         "title": "Selected Shorts"
#       },
#       {
#         "daysSinceLastListen": 322,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/381443514/recommendations",
#         "id": "381443514",
#         "notif_following": {
#           "default": "/topics/prod_followed_381443514",
#           "ios": "/topics/prod_followed_IOS_381443514"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381443514",
#           "ios": "/topics/prod_rated_IOS_381443514"
#         },
#         "rating": 0.3,
#         "title": "Diane Rehm: On My Mind"
#       },
#       {
#         "daysSinceLastListen": 405,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/381443519/recommendations",
#         "id": "381443519",
#         "notif_following": {
#           "default": "/topics/prod_followed_381443519",
#           "ios": "/topics/prod_followed_IOS_381443519"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381443519",
#           "ios": "/topics/prod_rated_IOS_381443519"
#         },
#         "rating": 0.25,
#         "title": "The Kojo Nnamdi Show"
#       },
#       {
#         "daysSinceLastListen": 439,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/381443522/recommendations",
#         "id": "381443522",
#         "notif_following": {
#           "default": "/topics/prod_followed_381443522",
#           "ios": "/topics/prod_followed_IOS_381443522"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381443522",
#           "ios": "/topics/prod_rated_IOS_381443522"
#         },
#         "rating": 0.7,
#         "title": "Classical 101 Podcasts"
#       },
#       {
#         "daysSinceLastListen": 128,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/381443773/recommendations",
#         "id": "381443773",
#         "notif_following": {
#           "default": "/topics/prod_followed_381443773",
#           "ios": "/topics/prod_followed_IOS_381443773"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381443773",
#           "ios": "/topics/prod_rated_IOS_381443773"
#         },
#         "rating": 0.65,
#         "title": "Jazz Northwest"
#       },
#       {
#         "daysSinceLastListen": 345,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/381443930/recommendations",
#         "id": "381443930",
#         "notif_following": {
#           "default": "/topics/prod_followed_381443930",
#           "ios": "/topics/prod_followed_IOS_381443930"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381443930",
#           "ios": "/topics/prod_rated_IOS_381443930"
#         },
#         "rating": 0.6,
#         "title": "Marketplace Tech with Molly Wood"
#       },
#       {
#         "daysSinceLastListen": 63,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/381444246/recommendations",
#         "id": "381444246",
#         "notif_following": {
#           "default": "/topics/prod_followed_381444246",
#           "ios": "/topics/prod_followed_IOS_381444246"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381444246",
#           "ios": "/topics/prod_rated_IOS_381444246"
#         },
#         "rating": 0.3,
#         "title": "PRI's The World: Latest Edition"
#       },
#       {
#         "daysSinceLastListen": 126,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/381444599/recommendations",
#         "id": "381444599",
#         "notif_following": {
#           "default": "/topics/prod_followed_381444599",
#           "ios": "/topics/prod_followed_IOS_381444599"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381444599",
#           "ios": "/topics/prod_rated_IOS_381444599"
#         },
#         "rating": 0.64,
#         "title": "Marketplace Morning Report with David Brancaccio"
#       },
#       {
#         "daysSinceLastListen": 299,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/381444650/recommendations",
#         "id": "381444650",
#         "notif_following": {
#           "default": "/topics/prod_followed_381444650",
#           "ios": "/topics/prod_followed_IOS_381444650"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381444650",
#           "ios": "/topics/prod_rated_IOS_381444650"
#         },
#         "rating": 0.58,
#         "title": "This American Life"
#       },
#       {
#         "daysSinceLastListen": 1076,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/381444775/recommendations",
#         "id": "381444775",
#         "notif_following": {
#           "default": "/topics/prod_followed_381444775",
#           "ios": "/topics/prod_followed_IOS_381444775"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381444775",
#           "ios": "/topics/prod_rated_IOS_381444775"
#         },
#         "rating": 0.2,
#         "title": "KCRW's The Business"
#       },
#       {
#         "daysSinceLastListen": 458,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/381444908/recommendations",
#         "id": "381444908",
#         "notif_following": {
#           "default": "/topics/prod_followed_381444908",
#           "ios": "/topics/prod_followed_IOS_381444908"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_381444908",
#           "ios": "/topics/prod_rated_IOS_381444908"
#         },
#         "rating": 0.5,
#         "title": "Fresh Air"
#       },
#       {
#         "daysSinceLastListen": 12,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/398630798/recommendations",
#         "id": "398630798",
#         "notif_following": {
#           "default": "/topics/prod_followed_398630798",
#           "ios": "/topics/prod_followed_IOS_398630798"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_398630798",
#           "ios": "/topics/prod_rated_IOS_398630798"
#         },
#         "rating": 0.69,
#         "title": "99% Invisible"
#       },
#       {
#         "daysSinceLastListen": 578,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/398634718/recommendations",
#         "id": "398634718",
#         "notif_following": {
#           "default": "/topics/prod_followed_398634718",
#           "ios": "/topics/prod_followed_IOS_398634718"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_398634718",
#           "ios": "/topics/prod_rated_IOS_398634718"
#         },
#         "rating": 0.45,
#         "title": "Song Exploder"
#       },
#       {
#         "daysSinceLastListen": 982,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/399939827/recommendations",
#         "id": "399939827",
#         "notif_following": {
#           "default": "/topics/prod_followed_399939827",
#           "ios": "/topics/prod_followed_IOS_399939827"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_399939827",
#           "ios": "/topics/prod_rated_IOS_399939827"
#         },
#         "rating": 0.3,
#         "title": "BackStory"
#       },
#       {
#         "daysSinceLastListen": 837,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/399943395/recommendations",
#         "id": "399943395",
#         "notif_following": {
#           "default": "/topics/prod_followed_399943395",
#           "ios": "/topics/prod_followed_IOS_399943395"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_399943395",
#           "ios": "/topics/prod_rated_IOS_399943395"
#         },
#         "rating": 0.2,
#         "title": "Radio Diaries"
#       },
#       {
#         "daysSinceLastListen": 294,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/413432287/recommendations",
#         "id": "413432287",
#         "notif_following": {
#           "default": "/topics/prod_followed_413432287",
#           "ios": "/topics/prod_followed_IOS_413432287"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_413432287",
#           "ios": "/topics/prod_rated_IOS_413432287"
#         },
#         "rating": 0.3,
#         "title": "Reply All"
#       },
#       {
#         "daysSinceLastListen": 566,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/413473054/recommendations",
#         "id": "413473054",
#         "notif_following": {
#           "default": "/topics/prod_followed_413473054",
#           "ios": "/topics/prod_followed_IOS_413473054"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_413473054",
#           "ios": "/topics/prod_rated_IOS_413473054"
#         },
#         "rating": 0.68,
#         "title": "the memory palace"
#       },
#       {
#         "daysSinceLastListen": 435,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/447248267/recommendations",
#         "id": "447248267",
#         "notif_following": {
#           "default": "/topics/prod_followed_447248267",
#           "ios": "/topics/prod_followed_IOS_447248267"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_447248267",
#           "ios": "/topics/prod_rated_IOS_447248267"
#         },
#         "rating": 0.3,
#         "title": "The Leap"
#       },
#       {
#         "daysSinceLastListen": 322,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/452538045/recommendations",
#         "id": "452538045",
#         "notif_following": {
#           "default": "/topics/prod_followed_452538045",
#           "ios": "/topics/prod_followed_IOS_452538045"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_452538045",
#           "ios": "/topics/prod_rated_IOS_452538045"
#         },
#         "rating": 0.5,
#         "title": "Freakonomics Radio"
#       },
#       {
#         "daysSinceLastListen": 707,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/452538884/recommendations",
#         "id": "452538884",
#         "notif_following": {
#           "default": "/topics/prod_followed_452538884",
#           "ios": "/topics/prod_followed_IOS_452538884"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_452538884",
#           "ios": "/topics/prod_rated_IOS_452538884"
#         },
#         "rating": 1,
#         "title": "Radiolab"
#       },
#       {
#         "daysSinceLastListen": 833,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/467100501/recommendations",
#         "id": "467100501",
#         "notif_following": {
#           "default": "/topics/prod_followed_467100501",
#           "ios": "/topics/prod_followed_IOS_467100501"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_467100501",
#           "ios": "/topics/prod_rated_IOS_467100501"
#         },
#         "rating": 0.25,
#         "title": "Esquire Classic Podcast"
#       },
#       {
#         "daysSinceLastListen": 299,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/468776545/recommendations",
#         "id": "468776545",
#         "notif_following": {
#           "default": "/topics/prod_followed_468776545",
#           "ios": "/topics/prod_followed_IOS_468776545"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_468776545",
#           "ios": "/topics/prod_rated_IOS_468776545"
#         },
#         "rating": 0.2,
#         "title": "Stuff To Blow Your Mind"
#       },
#       {
#         "daysSinceLastListen": 578,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/474245150/recommendations",
#         "id": "474245150",
#         "notif_following": {
#           "default": "/topics/prod_followed_474245150",
#           "ios": "/topics/prod_followed_IOS_474245150"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_474245150",
#           "ios": "/topics/prod_rated_IOS_474245150"
#         },
#         "rating": 0.45,
#         "title": "The West Wing Weekly"
#       },
#       {
#         "daysSinceLastListen": 531,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/477275336/recommendations",
#         "id": "477275336",
#         "notif_following": {
#           "default": "/topics/prod_followed_477275336",
#           "ios": "/topics/prod_followed_IOS_477275336"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_477275336",
#           "ios": "/topics/prod_rated_IOS_477275336"
#         },
#         "rating": 0.35,
#         "title": "Strong Opinions Loosely Held"
#       },
#       {
#         "daysSinceLastListen": 322,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/483855296/recommendations",
#         "id": "483855296",
#         "notif_following": {
#           "default": "/topics/prod_followed_483855296",
#           "ios": "/topics/prod_followed_IOS_483855296"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_483855296",
#           "ios": "/topics/prod_rated_IOS_483855296"
#         },
#         "rating": 0.3,
#         "title": "Love Me"
#       },
#       {
#         "daysSinceLastListen": 632,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/492161035/recommendations",
#         "id": "492161035",
#         "notif_following": {
#           "default": "/topics/prod_followed_492161035",
#           "ios": "/topics/prod_followed_IOS_492161035"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_492161035",
#           "ios": "/topics/prod_rated_IOS_492161035"
#         },
#         "rating": 0.45,
#         "title": "OPB's This Land Is Our Land"
#       },
#       {
#         "daysSinceLastListen": 479,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/495471150/recommendations",
#         "id": "495471150",
#         "notif_following": {
#           "default": "/topics/prod_followed_495471150",
#           "ios": "/topics/prod_followed_IOS_495471150"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_495471150",
#           "ios": "/topics/prod_rated_IOS_495471150"
#         },
#         "rating": 0.7,
#         "title": "Classical Classroom"
#       },
#       {
#         "daysSinceLastListen": 602,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/497539877/recommendations",
#         "id": "497539877",
#         "notif_following": {
#           "default": "/topics/prod_followed_497539877",
#           "ios": "/topics/prod_followed_IOS_497539877"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_497539877",
#           "ios": "/topics/prod_rated_IOS_497539877"
#         },
#         "rating": 0.45,
#         "title": "SCAREDIOTOPIA: Halloween in Radiotopia-land"
#       },
#       {
#         "daysSinceLastListen": 204,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/498875165/recommendations",
#         "id": "498875165",
#         "notif_following": {
#           "default": "/topics/prod_followed_498875165",
#           "ios": "/topics/prod_followed_IOS_498875165"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_498875165",
#           "ios": "/topics/prod_rated_IOS_498875165"
#         },
#         "rating": 0.2,
#         "title": "On Record with Julia Figueras"
#       },
#       {
#         "daysSinceLastListen": 148,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/500005/recommendations",
#         "id": "500005",
#         "notif_following": {
#           "default": "/topics/prod_followed_500005",
#           "ios": "/topics/prod_followed_IOS_500005"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_500005",
#           "ios": "/topics/prod_rated_IOS_500005"
#         },
#         "rating": 0.3,
#         "title": "NPR News Now"
#       },
#       {
#         "daysSinceLastListen": 537,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/503757628/recommendations",
#         "id": "503757628",
#         "notif_following": {
#           "default": "/topics/prod_followed_503757628",
#           "ios": "/topics/prod_followed_IOS_503757628"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_503757628",
#           "ios": "/topics/prod_rated_IOS_503757628"
#         },
#         "rating": 0.5,
#         "title": "Homecoming"
#       },
#       {
#         "daysSinceLastListen": 578,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510019/recommendations",
#         "id": "510019",
#         "notif_following": {
#           "default": "/topics/prod_followed_510019",
#           "ios": "/topics/prod_followed_IOS_510019"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510019",
#           "ios": "/topics/prod_rated_IOS_510019"
#         },
#         "rating": 0.38,
#         "title": "All Songs Considered"
#       },
#       {
#         "daysSinceLastListen": 460,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/510026/recommendations",
#         "id": "510026",
#         "notif_following": {
#           "default": "/topics/prod_followed_510026",
#           "ios": "/topics/prod_followed_IOS_510026"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510026",
#           "ios": "/topics/prod_rated_IOS_510026"
#         },
#         "rating": 0.7,
#         "title": "From the Top with Host Christopher O'Riley"
#       },
#       {
#         "daysSinceLastListen": 727,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510030/recommendations",
#         "id": "510030",
#         "notif_following": {
#           "default": "/topics/prod_followed_510030",
#           "ios": "/topics/prod_followed_IOS_510030"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510030",
#           "ios": "/topics/prod_rated_IOS_510030"
#         },
#         "rating": 0.45,
#         "title": "Engines Of Our Ingenuity"
#       },
#       {
#         "daysSinceLastListen": 1320,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510053/recommendations",
#         "id": "510053",
#         "notif_following": {
#           "default": "/topics/prod_followed_510053",
#           "ios": "/topics/prod_followed_IOS_510053"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510053",
#           "ios": "/topics/prod_rated_IOS_510053"
#         },
#         "rating": 0.33,
#         "title": "On Point"
#       },
#       {
#         "daysSinceLastListen": 124,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/510056/recommendations",
#         "id": "510056",
#         "notif_following": {
#           "default": "/topics/prod_followed_510056",
#           "ios": "/topics/prod_followed_IOS_510056"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510056",
#           "ios": "/topics/prod_rated_IOS_510056"
#         },
#         "rating": 0.71,
#         "title": "Piano Jazz Shorts"
#       },
#       {
#         "daysSinceLastListen": 1345,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510200/recommendations",
#         "id": "510200",
#         "notif_following": {
#           "default": "/topics/prod_followed_510200",
#           "ios": "/topics/prod_followed_IOS_510200"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510200",
#           "ios": "/topics/prod_rated_IOS_510200"
#         },
#         "rating": 0.2,
#         "title": "StoryCorps"
#       },
#       {
#         "daysSinceLastListen": 205,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510208/recommendations",
#         "id": "510208",
#         "notif_following": {
#           "default": "/topics/prod_followed_510208",
#           "ios": "/topics/prod_followed_IOS_510208"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510208",
#           "ios": "/topics/prod_rated_IOS_510208"
#         },
#         "rating": 0.2,
#         "title": "Car Talk"
#       },
#       {
#         "daysSinceLastListen": 480,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510253/recommendations",
#         "id": "510253",
#         "notif_following": {
#           "default": "/topics/prod_followed_510253",
#           "ios": "/topics/prod_followed_IOS_510253"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510253",
#           "ios": "/topics/prod_rated_IOS_510253"
#         },
#         "rating": 0.45,
#         "title": "Live In Concert from NPR's All Songs Considered"
#       },
#       {
#         "daysSinceLastListen": 1084,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510282/recommendations",
#         "id": "510282",
#         "notif_following": {
#           "default": "/topics/prod_followed_510282",
#           "ios": "/topics/prod_followed_IOS_510282"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510282",
#           "ios": "/topics/prod_rated_IOS_510282"
#         },
#         "rating": 0.33,
#         "title": "Pop Culture Happy Hour"
#       },
#       {
#         "daysSinceLastListen": 175,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/510289/recommendations",
#         "id": "510289",
#         "notif_following": {
#           "default": "/topics/prod_followed_510289",
#           "ios": "/topics/prod_followed_IOS_510289"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510289",
#           "ios": "/topics/prod_rated_IOS_510289"
#         },
#         "rating": 0.68,
#         "title": "Planet Money"
#       },
#       {
#         "daysSinceLastListen": 178,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/510298/recommendations",
#         "id": "510298",
#         "notif_following": {
#           "default": "/topics/prod_followed_510298",
#           "ios": "/topics/prod_followed_IOS_510298"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510298",
#           "ios": "/topics/prod_rated_IOS_510298"
#         },
#         "rating": 0.66,
#         "title": "TED Radio Hour"
#       },
#       {
#         "daysSinceLastListen": 905,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/510303/recommendations",
#         "id": "510303",
#         "notif_following": {
#           "default": "/topics/prod_followed_510303",
#           "ios": "/topics/prod_followed_IOS_510303"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510303",
#           "ios": "/topics/prod_rated_IOS_510303"
#         },
#         "rating": 0.68,
#         "title": "How To Do Everything"
#       },
#       {
#         "daysSinceLastListen": 684,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510307/recommendations",
#         "id": "510307",
#         "notif_following": {
#           "default": "/topics/prod_followed_510307",
#           "ios": "/topics/prod_followed_IOS_510307"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510307",
#           "ios": "/topics/prod_rated_IOS_510307"
#         },
#         "rating": 0.45,
#         "title": "Invisibilia"
#       },
#       {
#         "daysSinceLastListen": 448,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510308/recommendations",
#         "id": "510308",
#         "notif_following": {
#           "default": "/topics/prod_followed_510308",
#           "ios": "/topics/prod_followed_IOS_510308"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510308",
#           "ios": "/topics/prod_rated_IOS_510308"
#         },
#         "rating": 0.63,
#         "title": "Hidden Brain"
#       },
#       {
#         "daysSinceLastListen": 696,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510310/recommendations",
#         "id": "510310",
#         "notif_following": {
#           "default": "/topics/prod_followed_510310",
#           "ios": "/topics/prod_followed_IOS_510310"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510310",
#           "ios": "/topics/prod_rated_IOS_510310"
#         },
#         "rating": 0.41,
#         "title": "NPR Politics Podcast"
#       },
#       {
#         "daysSinceLastListen": 113,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510311/recommendations",
#         "id": "510311",
#         "notif_following": {
#           "default": "/topics/prod_followed_510311",
#           "ios": "/topics/prod_followed_IOS_510311"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510311",
#           "ios": "/topics/prod_rated_IOS_510311"
#         },
#         "rating": 0.3,
#         "title": "Embedded"
#       },
#       {
#         "daysSinceLastListen": 230,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510312/recommendations",
#         "id": "510312",
#         "notif_following": {
#           "default": "/topics/prod_followed_510312",
#           "ios": "/topics/prod_followed_IOS_510312"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510312",
#           "ios": "/topics/prod_rated_IOS_510312"
#         },
#         "rating": 0.25,
#         "title": "Code Switch"
#       },
#       {
#         "daysSinceLastListen": 515,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510313/recommendations",
#         "id": "510313",
#         "notif_following": {
#           "default": "/topics/prod_followed_510313",
#           "ios": "/topics/prod_followed_IOS_510313"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510313",
#           "ios": "/topics/prod_rated_IOS_510313"
#         },
#         "rating": 0.3,
#         "title": "How I Built This with Guy Raz"
#       },
#       {
#         "daysSinceLastListen": 168,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/510318/recommendations",
#         "id": "510318",
#         "notif_following": {
#           "default": "/topics/prod_followed_510318",
#           "ios": "/topics/prod_followed_IOS_510318"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510318",
#           "ios": "/topics/prod_rated_IOS_510318"
#         },
#         "rating": 0.4,
#         "title": "Up First"
#       },
#       {
#         "daysSinceLastListen": 12,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/510321/recommendations",
#         "id": "510321",
#         "notif_following": {
#           "default": "/topics/prod_followed_510321",
#           "ios": "/topics/prod_followed_IOS_510321"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_510321",
#           "ios": "/topics/prod_rated_IOS_510321"
#         },
#         "rating": 0.81,
#         "title": "Wow in the World"
#       },
#       {
#         "daysSinceLastListen": 22,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/512477927/recommendations",
#         "id": "512477927",
#         "notif_following": {
#           "default": "/topics/prod_followed_512477927",
#           "ios": "/topics/prod_followed_IOS_512477927"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_512477927",
#           "ios": "/topics/prod_rated_IOS_512477927"
#         },
#         "rating": 0.5,
#         "title": "The Daily"
#       },
#       {
#         "daysSinceLastListen": 480,
#         "following": true,
#         "href": "https://listening.api.npr.org/v2/aggregation/514401717/recommendations",
#         "id": "514401717",
#         "notif_following": {
#           "default": "/topics/prod_followed_514401717",
#           "ios": "/topics/prod_followed_IOS_514401717"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_514401717",
#           "ios": "/topics/prod_rated_IOS_514401717"
#         },
#         "rating": 0.5,
#         "title": "School Of Jazz"
#       },
#       {
#         "daysSinceLastListen": 330,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/524952613/recommendations",
#         "id": "524952613",
#         "notif_following": {
#           "default": "/topics/prod_followed_524952613",
#           "ios": "/topics/prod_followed_IOS_524952613"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_524952613",
#           "ios": "/topics/prod_rated_IOS_524952613"
#         },
#         "rating": 0.2,
#         "title": "Terrestrial"
#       },
#       {
#         "daysSinceLastListen": 821,
#         "following": false,
#         "href": "https://listening.api.npr.org/v2/aggregation/610087/recommendations",
#         "id": "610087",
#         "notif_following": {
#           "default": "/topics/prod_followed_610087",
#           "ios": "/topics/prod_followed_IOS_610087"
#         },
#         "notif_rated": {
#           "default": "/topics/prod_rated_610087",
#           "ios": "/topics/prod_rated_IOS_610087"
#         },
#         "rating": 0,
#         "title": "Nocturne"
#       }
#     ],
#     "cohort": {
#       "id": "F",
#       "name": "New baseline with Explore changes",
#       "public": "612"
#     },
#     "email": "perrydc@gmail.com",
#     "firstName": "Demian",
#     "gdpr": {
#       "isGdpr": false
#     },
#     "id": "1764670",
#     "lastName": "Perry",
#     "organizations": [
#       {
#         "call": "WAMU",
#         "city": "Washington",
#         "displayName": "WAMU 88.5",
#         "donationUrl": "http://wamu.org/support/donate/?utm_source=NPROne&utm_medium=app-referral&utm_content=20180606&utm_campaign=NPRdonate",
#         "id": "305",
#         "logo": "https://media.npr.org/images/stations/nprone_logos/wamu_fm.png",
#         "membership": {
#           "memberType": "Non-Member"
#         },
#         "notif_org": {
#           "default": "/topics/prod_org_305",
#           "ios": "/topics/prod_org_IOS_305"
#         },
#         "smallLogo": "https://media.npr.org/images/stations/logos/wamu_fm.gif"
#       }
#     ],
#     "totalListeningTime": "549324"
#   },
#   "errors": [],
#   "href": "https://api.npr.org/identity/v2/user",
#   "items": [],
#   "links": {
#     "organizations": [
#       {
#         "content-type": "application/json",
#         "href": "https://api.npr.org/listening/v2/organizations/305/recommendations"
#       }
#     ]
#   },
#   "version": "1.0"
# }

# %%
player = npr.One()
player.skip()
player.skip()
player.title
# Out:
# 'Miss America Contest To End Swimsuit Portion Of Competition'

# %%
print(npr.x)
# Out:
# station = npr.Station(305) # lookup station by orgId
# station.a # quick-reference of variables in namespace
# station.unwrap(station.stream) # some streams need to be unwrapped for use by FFMPEG
# station.pretty() # print raw api response
# s.find('88.5') # reverse lookup response keys by value
#
# stations = npr.Stations(38.9072,-77.0369) # npr.Stations('22205') | npr.Stations('WAMU')
# stations.station[0]['name'] # example of quick-reference across a list
#
# story = npr.Story(565664321) # lookup story by id
# story.title
#
# stories = npr.Stories() # lookup top stories
# stories.titles
#
# user = npr.User() # data on the logged in user
#
# player = npr.One() # create a NPR One player object
# player.skip() # player.complete()
#
# query = npr.Search('hidden')
#
# hiddenBrain = npr.Agg('510308') # the aggId is listed as the 'affiliation' in search
# hiddenBrain.pretty()
#
# explore = npr.Channels()
# explore.fetch(2) - fetch segments from third row of explore list
# explore.row.pretty()
#
# npr.clientauth()
# npr.auth()
# npr.deauth()
# npr.login()
# npr.logout()

# %%
ast = npr.Agg('565664321')
ast.pretty()
# Out:
# {
#   "attributes": {
#     "affiliation": "565664321",
#     "affiliationMeta": {
#       "following": false,
#       "href": "https://listening.api.npr.org/v2/aggregation/565664321/recommendations",
#       "id": "565664321",
#       "notif_following": {
#         "default": "/topics/prod_followed_565664321",
#         "ios": "/topics/prod_followed_IOS_565664321"
#       },
#       "notif_rated": {
#         "default": "/topics/prod_rated_565664321",
#         "ios": "/topics/prod_rated_IOS_565664321"
#       },
#       "title": "Stories from NPR"
#     },
#     "description": "Assorted stories from NPR",
#     "provider": "NPR",
#     "station": "NPR",
#     "title": "Stories from NPR",
#     "type": "aggregation"
#   },
#   "errors": [],
#   "href": "https://listening.api.npr.org/v2/aggregation/565664321/recommendations",
#   "items": [
#     {
#       "attributes": {
#         "audioTitle": "Craft Hard Cider Is On A Roll. How Ya Like Them Apples?",
#         "date": "2017-12-02T08:00:00-05:00",
#         "description": "Hard cider is having a hot moment. Hotter still, if it's locally made and distributed. Over the past four years, the number of cideries across the country has doubled.",
#         "duration": 178,
#         "geofence": {
#           "countries": [],
#           "restricted": false
#         },
#         "primary": true,
#         "provider": "NPR",
#         "rating": {
#           "affiliations": [],
#           "channel": "npr",
#           "cohort": "F",
#           "duration": 178,
#           "elapsed": 0,
#           "mediaId": "565664321:568325925",
#           "origin": "LTNUPLINK",
#           "rating": "START",
#           "timestamp": "2018-06-06T12:06:52-0400"
#         },
#         "rationale": "",
#         "skippable": true,
#         "slug": "the salt",
#         "title": "Craft Hard Cider Is On A Roll. How Ya Like Them Apples?",
#         "type": "audio",
#         "uid": "565664321:568325925"
#       },
#       "errors": [],
#       "href": "https://listening.api.npr.org/v2/recommendations?channel=npr&sharedMediaId=565664321:568325925",
#       "items": [],
#       "links": {
#         "audio": [
#           {
#             "content-type": "audio/mp3",
#             "href": "https://ondemand.npr.org/anon.npr-mp3/npr/npr1alt/2017/12/20171204_npr1alt_cider_npr_one_corrected.mp3?orgId=1&topicId=1053&d=178&story=565664321&NPROne=true"
#           },
#           {
#             "content-type": "audio/aac",
#             "href": "https://ondemand.npr.org/npr-mp4/npr/npr1alt/2017/12/20171204_npr1alt_cider_npr_one_corrected.mp4?orgId=1&topicId=1053&d=178&story=565664321&NPROne=true"
#           }
#         ],
#         "image": [
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-3-faacbc8ae4f0c7fda7c904e57d3e914c6b491bc4.jpg?s=600",
#             "image": "565993509",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "standard"
#           },
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-3_sq-c58519a543e8b440498e6e9be09502eed3b2fb07.jpg?s=600",
#             "image": "565993509",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "square"
#           },
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-3_wide-7eb1c146ac4e933f99e5559afdca69edd3093d3a.jpg?s=600",
#             "image": "565993509",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "wide"
#           },
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-3_custom-19468347fbe44b8e807df36686e54ab0d6ee2f22.jpg?s=600",
#             "image": "565993509",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "enlargement"
#           },
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-3_custom-19468347fbe44b8e807df36686e54ab0d6ee2f22.jpg?s=600",
#             "image": "565993509",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "custom"
#           },
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-2_vert-70d44d5a75d6cbeca81d39ff873a3585268bcf79.jpg?s=600",
#             "image": "565994432",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "enlargement"
#           },
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-2_vert-70d44d5a75d6cbeca81d39ff873a3585268bcf79.jpg?s=600",
#             "image": "565994432",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "vertical"
#           },
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-1-d25da36cdbdf19d7581aded60b6978ba000753f9.jpg?s=600",
#             "image": "565994125",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "standard"
#           },
#           {
#             "content-type": "image/jpeg",
#             "href": "https://media.npr.org/assets/img/2017/11/22/hard_cider-1-d25da36cdbdf19d7581aded60b6978ba000753f9.jpg?s=600",
#             "image": "565994125",
#             "provider": "Adhiti Bandlamudi/NPR",
#             "rel": "enlargement"
#           }
#         ],
#         "onramps": [
#           {
#             "content-type": "text/html",
#             "href": "http://one.npr.org/i/565664321:568325925"
#           }
#         ],
#         "ratings": [
#           {
#             "content-type": "application/json",
#             "href": "https://listening.api.npr.org/v2/ratings?recommend=false"
#           },
#           {
#             "content-type": "application/json",
#             "href": "https://listening.api.npr.org/v2/ratings?recommend=false"
#           }
#         ],
#         "recommendations": [
#           {
#             "content-type": "application/json",
#             "href": "https://listening.api.npr.org/v2/ratings?recommend=true&channel=npr&prevStories=1&queued=%5B%5D&flow=0"
#           }
#         ],
#         "web": [
#           {
#             "content-type": "text/html",
#             "href": "https://www.npr.org/sections/thesalt/2017/12/02/565664321/craft-hard-cider-is-on-a-roll-how-ya-like-them-apples"
#           },
#           {
#             "content-type": "application/xml",
#             "href": "http://api.npr.org/query?id=565664321&apiKey=MDI5NDI3MDQwMDE0ODMwMzg1MDUwN2U2OA000"
#           },
#           {
#             "content-type": "text/html",
#             "href": "http://n.pr/2mT7UjF"
#           },
#           {
#             "content-type": "text/html",
#             "href": "https://www.npr.org/player/embed/565664321/568325925",
#             "rel": "embed"
#           }
#         ]
#       },
#       "version": "1.0"
#     }
#   ],
#   "links": {
#     "more": [
#       {
#         "content-type": "application/json",
#         "href": "https://listening.api.npr.org/v2/aggregation/565664321/recommendations?startNum=11&origin=LTNUPLINK"
#       }
#     ],
#     "web": [
#       {
#         "content-type": "application/xml",
#         "href": "http://api.npr.org/query?id=565664321&apiKey=MDI5NDI3MDQwMDE0ODMwMzg1MDUwN2U2OA000"
#       },
#       {
#         "content-type": "text/html",
#         "href": "https://www.npr.org/sections/thesalt/2017/12/02/565664321/craft-hard-cider-is-on-a-roll-how-ya-like-them-apples"
#       }
#     ]
#   },
#   "version": "1.0"
# }
